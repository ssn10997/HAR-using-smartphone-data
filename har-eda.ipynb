# %% [markdown]
# <html><h1><center>Human Activity Recognition with Smartphones</center></h1></html>

# %% [markdown]
# <!-- <br> -->
# This project builds a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs,
# Sitting, Standing or Laying.
#
# 30 individuals, referred to as subjects in this dataset, carried a smartphone on their waist while performing their daily activities. The smartphone was set up to capture data from two sensors, namely accelerometer and gyroscope. To create the dataset, the researchers of the study extracted features from the time series data and generated it by moving a window of fixed-width (2.56 seconds) over the data. The windows had a 50% overlap, resulting in equally spaced data points (1.28 seconds). The experiment was recorded on video to manually label the data.

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('/kaggle/input/uci-har-dataset/UCI HAR Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ### Getting the  train data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('/kaggle/input/uci-har-dataset/UCI HAR Dataset/train/X_train.txt', delim_whitespace=True, header=None)
X_train.columns = [features]
# add subject column to the dataframe
X_train['subject'] = pd.read_csv('/kaggle/input/uci-har-dataset/UCI HAR Dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('/kaggle/input/uci-har-dataset/UCI HAR Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample(2)
# Out:
#      tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 2729          0.277161         -0.019894         -0.111002        -0.995972
# 1470          0.246255         -0.039082         -0.114684        -0.318453
#
#      tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 2729        -0.964298        -0.994067        -0.996442        -0.963813
# 1470        -0.336475        -0.003599        -0.381447        -0.343053
#
#      tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 2729        -0.993115        -0.936600  ...                   -0.057454
# 1470         0.045346        -0.112486  ...                    0.110390
#
#      angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 2729                            -0.058791                         0.126709
# 1470                             0.457350                        -0.744585
#
#      angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 2729                             0.715015            -0.804707
# 1470                            -0.831943            -0.385926
#
#      angle(Y,gravityMean) angle(Z,gravityMean) subject Activity  \
# 2729             0.231682            -0.002577      15        5
# 1470             0.218434             0.436918       7        2
#
#           ActivityName
# 2729          STANDING
# 1470  WALKING_UPSTAIRS
#
# [2 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ### Getting the  train data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('/kaggle/input/uci-har-dataset/UCI HAR Dataset/test/X_test.txt', delim_whitespace=True, header=None)
X_test.columns = [features]
# add subject column to the dataframe
X_test['subject'] = pd.read_csv('/kaggle/input/uci-har-dataset/UCI HAR Dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('/kaggle/input/uci-har-dataset/UCI HAR Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample(2)
# Out:
#      tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 590           0.378995         -0.050250         -0.076373         0.092684
# 1456          0.216092         -0.004176         -0.150084        -0.074292
#
#      tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 590          0.050995        -0.389874         0.006004        -0.024501
# 1456        -0.062267        -0.566137        -0.134156        -0.118484
#
#      tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 590         -0.426961         0.359865  ...                   -0.543173
# 1456        -0.566414         0.179667  ...                    0.462363
#
#      angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 590                             -0.659193                         0.970514
# 1456                            -0.693531                         0.581604
#
#      angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 590                             -0.154647            -0.873279
# 1456                             0.851944            -0.871478
#
#      angle(Y,gravityMean) angle(Z,gravityMean) subject Activity  \
# 590              0.094342            -0.075194       4        3
# 1456             0.184557             0.039629      12        1
#
#             ActivityName
# 590   WALKING_DOWNSTAIRS
# 1456             WALKING
#
# [2 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Time to Data Cleaning

# %% [markdown]
# ### 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3029: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ### 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ### 3. Save this dataframe in a csv files

# %%
train.to_csv('/kaggle/working/train.csv', index=False)
test.to_csv('/kaggle/working/test.csv', index=False)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Obtain the train and test data

# %%
train = pd.read_csv('/kaggle/working/train.csv')
test = pd.read_csv('/kaggle/working/test.csv')
print(train.shape, test.shape)
# Out:
# (7352, 564) (2947, 564)

# %% [markdown]
# ### All the feature name with lots of unnecessary singhs:  Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ### 1. investigate participants activity durations.
# - Since the dataset has been created in a scientific environment nearly equal preconditions for the participants can be assumed. Let us investigate their activity durations.

# %%
import matplotlib as mlt
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# - Nearly all participants have more data for walking upstairs than downstairs. Assuming an equal number of up- and down-walks the participants need longer walking upstairs.

# %% [markdown]
# ### How Are The ActivityName Distributed?

# %%
import plotly
import plotly.graph_objects as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot


# Plotting data
label_counts = train['ActivityName'].value_counts()

# Get colors
n = label_counts.shape[0]
colormap = plt.get_cmap('viridis')
colors = [mlt.colors.to_hex(colormap(col)) for col in np.arange(0, 1.01, 1/(n-1))]

# Create plot
data = go.Bar(x = label_counts.index,
              y = label_counts,
              marker = dict(color = colors))

layout = go.Layout(title = 'Smartphone ActivityName Distribution',
                   xaxis = dict(title = 'ActivityName'),
                   yaxis = dict(title = 'Count'))

fig = go.Figure(data=[data], layout=layout)
fig.show()
#iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="0a8de2a4-dbf5-4c94-89d4-8b44a87b0f4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a8de2a4-dbf5-4c94-89d4-8b44a87b0f4f")) {                    Plotly.newPlot(                        "0a8de2a4-dbf5-4c94-89d4-8b44a87b0f4f",                        [{"marker":{"color":["#440154","#414487","#2a788e","#22a884","#7ad151","#fde725"]},"x":["LAYING","STANDING","SITTING","WALKING","WALKING_UPSTAIRS","WALKING_DOWNSTAIRS"],"y":[1407,1374,1286,1226,1073,986],"type":"bar"}],                        {"title":{"text":"Smartphone ActivityName Distribution"},"xaxis":{"title":{"text":"ActivityName"}},"yaxis":{"title":{"text":"Count"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{" ...
#
# var gd = document.getElementById('0a8de2a4-dbf5-4c94-89d4-8b44a87

# %% [markdown]
# - Although there are fluctuations in the label counts, the labels are quite equally distributed.
#
# - Assuming the participants had to walk the same number of stairs upwards as well as downwards and knowing the smartphones had a constant sampling rate, there should be the same amount of datapoints for walking upstairs and downstairs.
# - Disregarding the possibility of flawed data, the participants seem to walk roughly 10% faster downwards.

# %% [markdown]
# ### 2. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 3. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', height=5,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.960,12), xytext=(-0.5, 15), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# - As aspected from most real world data, when participants are moving the data is normally distributed with some long tail.

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.08, -0.2, 0.1, 20])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:20: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# - We can see clearly here, the distribuation of Stationary Activities and Moving Activities.

# %% [markdown]
# ### 4. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 5. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# - If angleX,gravityMean > 0 then Activity is Laying.
# - We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# ## Apply t-sne on the data
# #### Are The Activities Separable?
# - The dataset is geared towards classifying the activity of the participant. Let us investigate the separability of the classes.

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, height=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.004s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 1.968s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.597443
# [t-SNE] Computed conditional probabilities in 0.019s
# [t-SNE] Iteration 50: error = 124.8174896, gradient norm = 0.0251770 (50 iterations in 5.198s)
# [t-SNE] Iteration 100: error = 107.5007858, gradient norm = 0.0269167 (50 iterations in 3.006s)
# [t-SNE] Iteration 150: error = 101.0602646, gradient norm = 0.0182934 (50 iterations in 2.406s)
# [t-SNE] Iteration 200: error = 97.5273438, gradient norm = 0.0148122 (50 iterations in 2.264s)
# [t-SNE] Iteration 250: error = 95.1446381, gradient norm = 0.0153976 (50 iterations in 2.229s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.144638
# [t-SNE] Iteration 300: error = 4.1181021, gradient norm = 0.0015712 (50 iterations in 2.242s)
# [t-SNE] Iteration 350: error = 3.2053301, gradient norm = 0.0010011 (50 iterations in 2.358s)
# [t-SNE] Iteration 400: error = 2.7749252, gradient norm = 0.0007218 (50 iterations in 2.415s)
# [t-SNE] Iteration 450: error = 2.5110278, gradient norm = 0.0005644 (50 iterations in 2.502s)
# [t-SNE] Iteration 500: error = 2.3276384, gradient norm = 0.0004748 (50 iterations in 2.425s)
# [t-SNE] Iteration 550: error = 2.1892126, gradient norm = 0.0004188 (50 iterations in 2.408s)
# [t-SNE] Iteration 600: error = 2.0797608, gradient norm = 0.0003659 (50 iterations in 2.448s)
# [t-SNE] Iteration 650: error = 1.9898212, gradient norm = 0.0003297 (50 iterations in 2.424s)
# [t-SNE] Iteration 700: error = 1.9139951, gradient norm = 0.0003006 (50 iterations in 2.427s)
# [t-SNE] Iteration 750: error = 1.8488781, gradient norm = 0.0002792 (50 iterations in 2.446s)
# [t-SNE] Iteration 800: error = 1.7922221, gradient norm = 0.0002575 (50 iterations in 2.444s)
# [t-SNE] Iteration 850: error = 1.7421885, gradient norm = 0.0002389 (50 iterations in 2.468s)
# [t-SNE] Iteration 900: error = 1.6974571, gradient norm = 0.0002245 (50 iterations in 2.449s)
# [t-SNE] Iteration 950: error = 1.6571461, gradient norm = 0.0002117 (50 iterations in 2.441s)
# [t-SNE] Iteration 1000: error = 1.6206614, gradient norm = 0.0002005 (50 iterations in 2.468s)
# [t-SNE] KL divergence after 1000 iterations: 1.620661
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.003s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 1.452s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961446
# [t-SNE] Computed conditional probabilities in 0.041s
# [t-SNE] Iteration 50: error = 114.0829086, gradient norm = 0.0177263 (50 iterations in 4.415s)
# [t-SNE] Iteration 100: error = 97.8344345, gradient norm = 0.0147683 (50 iterations in 2.989s)
# [t-SNE] Iteration 150: error = 93.3778000, gradient norm = 0.0106314 (50 iterations in 2.481s)
# [t-SNE] Iteration 200: error = 91.2489014, gradient norm = 0.0074031 (50 iterations in 2.477s)
# [t-SNE] Iteration 250: error = 90.0358810, gradient norm = 0.0056863 (50 iterations in 2.438s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.035881
# [t-SNE] Iteration 300: error = 3.5716667, gradient norm = 0.0014590 (50 iterations in 2.331s)
# [t-SNE] Iteration 350: error = 2.8151865, gradient norm = 0.0007538 (50 iterations in 2.359s)
# [t-SNE] Iteration 400: error = 2.4344685, gradient norm = 0.0005253 (50 iterations in 2.405s)
# [t-SNE] Iteration 450: error = 2.2164376, gradient norm = 0.0004067 (50 iterations in 2.397s)
# [t-SNE] Iteration 500: error = 2.0714629, gradient norm = 0.0003333 (50 iterations in 2.400s)
# [t-SNE] Iteration 550: error = 1.9660828, gradient norm = 0.0002834 (50 iterations in 2.425s)
# [t-SNE] Iteration 600: error = 1.8849951, gradient norm = 0.0002455 (50 iterations in 2.423s)
# [t-SNE] Iteration 650: error = 1.8199446, gradient norm = 0.0002189 (50 iterations in 2.515s)
# [t-SNE] Iteration 700: error = 1.7662767, gradient norm = 0.0001972 (50 iterations in 2.442s)
# [t-SNE] Iteration 750: error = 1.7210220, gradient norm = 0.0001800 (50 iterations in 2.445s)
# [t-SNE] Iteration 800: error = 1.6822350, gradient norm = 0.0001658 (50 iterations in 2.458s)
# [t-SNE] Iteration 850: error = 1.6484059, gradient norm = 0.0001533 (50 iterations in 2.501s)
# [t-SNE] Iteration 900: error = 1.6185856, gradient norm = 0.0001433 (50 iterations in 2.475s)
# [t-SNE] Iteration 950: error = 1.5919373, gradient norm = 0.0001344 (50 iterations in 2.486s)
# [t-SNE] Iteration 1000: error = 1.5681194, gradient norm = 0.0001257 (50 iterations in 2.459s)
# [t-SNE] KL divergence after 1000 iterations: 1.568119
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.004s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 1.450s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133827
# [t-SNE] Computed conditional probabilities in 0.081s
# [t-SNE] Iteration 50: error = 106.2435837, gradient norm = 0.0115695 (50 iterations in 4.465s)
# [t-SNE] Iteration 100: error = 91.1930923, gradient norm = 0.0123941 (50 iterations in 3.221s)
# [t-SNE] Iteration 150: error = 87.6471176, gradient norm = 0.0079132 (50 iterations in 2.705s)
# [t-SNE] Iteration 200: error = 86.2350998, gradient norm = 0.0052030 (50 iterations in 2.596s)
# [t-SNE] Iteration 250: error = 85.4569397, gradient norm = 0.0038815 (50 iterations in 2.545s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.456940
# [t-SNE] Iteration 300: error = 3.1391909, gradient norm = 0.0013946 (50 iterations in 2.474s)
# [t-SNE] Iteration 350: error = 2.4931307, gradient norm = 0.0006497 (50 iterations in 2.443s)
# [t-SNE] Iteration 400: error = 2.1729999, gradient norm = 0.0004239 (50 iterations in 2.489s)
# [t-SNE] Iteration 450: error = 1.9882154, gradient norm = 0.0003124 (50 iterations in 2.495s)
# [t-SNE] Iteration 500: error = 1.8702511, gradient norm = 0.0002519 (50 iterations in 2.497s)
# [t-SNE] Iteration 550: error = 1.7870934, gradient norm = 0.0002094 (50 iterations in 2.489s)
# [t-SNE] Iteration 600: error = 1.7245737, gradient norm = 0.0001815 (50 iterations in 2.508s)
# [t-SNE] Iteration 650: error = 1.6756186, gradient norm = 0.0001586 (50 iterations in 2.547s)
# [t-SNE] Iteration 700: error = 1.6357950, gradient norm = 0.0001438 (50 iterations in 2.503s)
# [t-SNE] Iteration 750: error = 1.6030376, gradient norm = 0.0001318 (50 iterations in 2.675s)
# [t-SNE] Iteration 800: error = 1.5757076, gradient norm = 0.0001203 (50 iterations in 2.520s)
# [t-SNE] Iteration 850: error = 1.5525047, gradient norm = 0.0001112 (50 iterations in 2.546s)
# [t-SNE] Iteration 900: error = 1.5326183, gradient norm = 0.0001043 (50 iterations in 2.527s)
# [t-SNE] Iteration 950: error = 1.5152228, gradient norm = 0.0000982 (50 iterations in 2.519s)
# [t-SNE] Iteration 1000: error = 1.5000527, gradient norm = 0.0000936 (50 iterations in 2.534s)
# [t-SNE] KL divergence after 1000 iterations: 1.500053
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.003s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 1.467s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274336
# [t-SNE] Computed conditional probabilities in 0.157s
# [t-SNE] Iteration 50: error = 97.1644592, gradient norm = 0.0219386 (50 iterations in 5.449s)
# [t-SNE] Iteration 100: error = 83.9079056, gradient norm = 0.0098371 (50 iterations in 3.866s)
# [t-SNE] Iteration 150: error = 81.9501572, gradient norm = 0.0033381 (50 iterations in 3.285s)
# [t-SNE] Iteration 200: error = 81.2324524, gradient norm = 0.0026165 (50 iterations in 3.336s)
# [t-SNE] Iteration 250: error = 80.8585052, gradient norm = 0.0018071 (50 iterations in 3.227s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.858505
# [t-SNE] Iteration 300: error = 2.7013543, gradient norm = 0.0013024 (50 iterations in 3.010s)
# [t-SNE] Iteration 350: error = 2.1668398, gradient norm = 0.0005769 (50 iterations in 2.736s)
# [t-SNE] Iteration 400: error = 1.9169136, gradient norm = 0.0003486 (50 iterations in 2.714s)
# [t-SNE] Iteration 450: error = 1.7704957, gradient norm = 0.0002483 (50 iterations in 2.734s)
# [t-SNE] Iteration 500: error = 1.6763444, gradient norm = 0.0001930 (50 iterations in 2.798s)
# [t-SNE] Iteration 550: error = 1.6120187, gradient norm = 0.0001593 (50 iterations in 2.768s)
# [t-SNE] Iteration 600: error = 1.5656846, gradient norm = 0.0001347 (50 iterations in 2.776s)
# [t-SNE] Iteration 650: error = 1.5312493, gradient norm = 0.0001192 (50 iterations in 2.781s)
# [t-SNE] Iteration 700: error = 1.5043327, gradient norm = 0.0001069 (50 iterations in 2.833s)
# [t-SNE] Iteration 750: error = 1.4826247, gradient norm = 0.0000984 (50 iterations in 2.844s)
# [t-SNE] Iteration 800: error = 1.4653807, gradient norm = 0.0000897 (50 iterations in 2.794s)
# [t-SNE] Iteration 850: error = 1.4509910, gradient norm = 0.0000851 (50 iterations in 2.791s)
# [t-SNE] Iteration 900: error = 1.4392875, gradient norm = 0.0000784 (50 iterations in 2.819s)
# [t-SNE] Iteration 950: error = 1.4293410, gradient norm = 0.0000778 (50 iterations in 2.764s)
# [t-SNE] Iteration 1000: error = 1.4210902, gradient norm = 0.0000735 (50 iterations in 2.796s)
# [t-SNE] KL divergence after 1000 iterations: 1.421090
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.004s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 1.593s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.401s
# [t-SNE] Iteration 50: error = 86.0936050, gradient norm = 0.0269783 (50 iterations in 5.895s)
# [t-SNE] Iteration 100: error = 76.0346451, gradient norm = 0.0049635 (50 iterations in 5.039s)
# [t-SNE] Iteration 150: error = 74.9992981, gradient norm = 0.0031965 (50 iterations in 4.481s)
# [t-SNE] Iteration 200: error = 74.4523468, gradient norm = 0.0017131 (50 iterations in 4.395s)
# [t-SNE] Iteration 250: error = 74.1961823, gradient norm = 0.0017395 (50 iterations in 4.469s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.196182
# [t-SNE] Iteration 300: error = 2.1813695, gradient norm = 0.0012186 (50 iterations in 3.970s)
# [t-SNE] Iteration 350: error = 1.7748116, gradient norm = 0.0005081 (50 iterations in 3.647s)
# [t-SNE] Iteration 400: error = 1.6008223, gradient norm = 0.0002953 (50 iterations in 3.654s)
# [t-SNE] Iteration 450: error = 1.5042392, gradient norm = 0.0001952 (50 iterations in 3.578s)
# [t-SNE] Iteration 500: error = 1.4423114, gradient norm = 0.0001499 (50 iterations in 3.608s)
# [t-SNE] Iteration 550: error = 1.3997768, gradient norm = 0.0001146 (50 iterations in 4.009s)
# [t-SNE] Iteration 600: error = 1.3700683, gradient norm = 0.0000961 (50 iterations in 3.665s)
# [t-SNE] Iteration 650: error = 1.3484793, gradient norm = 0.0000822 (50 iterations in 3.656s)
# [t-SNE] Iteration 700: error = 1.3323257, gradient norm = 0.0000741 (50 iterations in 3.688s)
# [t-SNE] Iteration 750: error = 1.3205285, gradient norm = 0.0000674 (50 iterations in 3.656s)
# [t-SNE] Iteration 800: error = 1.3116672, gradient norm = 0.0000678 (50 iterations in 3.675s)
# [t-SNE] Iteration 850: error = 1.3051885, gradient norm = 0.0000616 (50 iterations in 3.723s)
# [t-SNE] Iteration 900: error = 1.2999662, gradient norm = 0.0000561 (50 iterations in 3.677s)
# [t-SNE] Iteration 950: error = 1.2953482, gradient norm = 0.0000549 (50 iterations in 3.834s)
# [t-SNE] Iteration 1000: error = 1.2912207, gradient norm = 0.0000529 (50 iterations in 3.705s)
# [t-SNE] KL divergence after 1000 iterations: 1.291221
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...

# %% [markdown]
# - We can clearly see the TSNE cluster, All the Activity are clean seperate except "Standing" and "Sitting".
